# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhilvkth/computer_vision/blob/main/RGB_to_grayscale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import cv2
import matplotlib.pyplot as plt

# Mount Google Drive
drive.mount('/content/gdrive')

# Replace 'path/to/your/image.jpg' with the actual path on your Google Drive
image_path = '/content/duck.webp'

# Load an RGB image
rgb_image = cv2.imread(image_path)

# Check if the image was loaded successfully
if rgb_image is None:
    print(f"Error: Unable to load the image at {image_path}")
else:
    # Convert RGB to Grayscale
    gray_image = cv2.cvtColor(rgb_image, cv2.COLOR_BGR2GRAY)

    # Display the original and grayscale images
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(rgb_image, cv2.COLOR_BGR2RGB))
    plt.title('Original RGB Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(gray_image, cmap='gray')
    plt.title('Grayscale Image')
    plt.axis('off')

    plt.show()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
